# %% [markdown]
# <a href="https://colab.research.google.com/github/Mohit501/Applied-Data-Science-Capstone/blob/main/Segmenting_and_Clustering_Neighbourhoods_of_Toronto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install geocoder

# %% [markdown]
# ## Importing required libraries

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ## Loading Data

# %%
url = "https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"
extracting_data = requests.get(url).text
wiki_data = BeautifulSoup(extracting_data, 'lxml')

# %% [markdown]
# ## Creating a Data Frame

# %%
column_names = ['Postalcode','Borough','Neighborhood']
toronto = pd.DataFrame(columns = column_names)

content = wiki_data.find('div', class_='mw-parser-output')
table = content.table.tbody
postcode = 0
borough = 0
neighborhood = 0

for tr in table.find_all('tr'):
    i = 0
    for td in tr.find_all('td'):
        if i == 0:
            postcode = td.text
            i = i + 1
        elif i == 1:
            borough = td.text
            i = i + 1
        elif i == 2: 
            neighborhood = td.text.strip('\n').replace(']','')
    toronto = toronto.append({'Postalcode': postcode,'Borough': borough,'Neighborhood': neighborhood},ignore_index=True)

# %%
toronto
# Out:
#                                            Postalcode  ...                                       Neighborhood
# 0                               \nM1ANot assigned\n\n  ...                     M9AEtobicoke(Islington Avenue)
# 1               \nM1BScarborough(Malvern / Rouge)\n\n  ...  M9BEtobicoke(West Deane Park / Princess Garden...
# 2   \nM1CScarborough(Rouge Hill / Port Union / Hig...  ...  M9CEtobicoke(Eringate / Bloordale Gardens / Ol...
# 3   \nM1EScarborough(Guildwood / Morningside / Wes...  ...                                    M9ENot assigned
# 4                        \nM1GScarborough(Woburn)\n\n  ...                                    M9GNot assigned
# 5                     \nM1HScarborough(Cedarbrae)\n\n  ...                                    M9HNot assigned
# 6           \nM1JScarborough(Scarborough Village)\n\n  ...                                    M9JNot assigned
# ...

# %%
toronto = toronto[toronto.Borough!='Not assigned']
toronto = toronto[toronto.Borough!= 0]
toronto.reset_index(drop = True, inplace = True)
i = 0
for i in range(0,toronto.shape[0]):
    if toronto.iloc[i][2] == 'Not assigned':
        toronto.iloc[i][2] = toronto.iloc[i][1]
        i = i+1

# %%
toronto
# Out:
#                                            Postalcode  ...                                       Neighborhood
# 0                               \nM1ANot assigned\n\n  ...                     M9AEtobicoke(Islington Avenue)
# 1               \nM1BScarborough(Malvern / Rouge)\n\n  ...  M9BEtobicoke(West Deane Park / Princess Garden...
# 2   \nM1CScarborough(Rouge Hill / Port Union / Hig...  ...  M9CEtobicoke(Eringate / Bloordale Gardens / Ol...
# 3   \nM1EScarborough(Guildwood / Morningside / Wes...  ...                                    M9ENot assigned
# 4                        \nM1GScarborough(Woburn)\n\n  ...                                    M9GNot assigned
# 5                     \nM1HScarborough(Cedarbrae)\n\n  ...                                    M9HNot assigned
# 6           \nM1JScarborough(Scarborough Village)\n\n  ...                                    M9JNot assigned
# ...

# %%
df = toronto.groupby(['Postalcode','Borough'])['Neighborhood'].apply(', '.join).reset_index()
df
# Out:
#                                            Postalcode  ...                                       Neighborhood
# 0                               \nM1ANot assigned\n\n  ...                     M9AEtobicoke(Islington Avenue)
# 1               \nM1BScarborough(Malvern / Rouge)\n\n  ...  M9BEtobicoke(West Deane Park / Princess Garden...
# 2   \nM1CScarborough(Rouge Hill / Port Union / Hig...  ...  M9CEtobicoke(Eringate / Bloordale Gardens / Ol...
# 3   \nM1EScarborough(Guildwood / Morningside / Wes...  ...                                    M9ENot assigned
# 4                        \nM1GScarborough(Woburn)\n\n  ...                                    M9GNot assigned
# 5                     \nM1HScarborough(Cedarbrae)\n\n  ...                                    M9HNot assigned
# 6           \nM1JScarborough(Scarborough Village)\n\n  ...                                    M9JNot assigned
# ...

# %%
df = df.dropna()
empty = 'Not assigned'
df = df[(df.Postalcode != empty ) & (df.Borough != empty) & (df.Neighborhood != empty)]

# %%
def neighborhood_list(grouped):    
    return ', '.join(sorted(grouped['Neighborhood'].tolist()))
                    
grp = df.groupby(['Postalcode', 'Borough'])
df_2 = grp.apply(neighborhood_list).reset_index(name='Neighborhood')

# %%
df_2
# Out:
#                                            Postalcode  ...                                       Neighborhood
# 0                               \nM1ANot assigned\n\n  ...                     M9AEtobicoke(Islington Avenue)
# 1               \nM1BScarborough(Malvern / Rouge)\n\n  ...  M9BEtobicoke(West Deane Park / Princess Garden...
# 2   \nM1CScarborough(Rouge Hill / Port Union / Hig...  ...  M9CEtobicoke(Eringate / Bloordale Gardens / Ol...
# 3   \nM1EScarborough(Guildwood / Morningside / Wes...  ...                                    M9ENot assigned
# 4                        \nM1GScarborough(Woburn)\n\n  ...                                    M9GNot assigned
# 5                     \nM1HScarborough(Cedarbrae)\n\n  ...                                    M9HNot assigned
# 6           \nM1JScarborough(Scarborough Village)\n\n  ...                                    M9JNot assigned
# ...
